# %%
from PIL import Image
img=Image.open(r"C:\Users\Son\Pictures\Screenshots\스크린샷 2025-08-16 174801.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1118x792>

# %%
import sys
from collections import deque
sys.setrecursionlimit(10**6)

input = sys.stdin.readline


N,K=map(int,input().split())

def bfs(v,target_pos):
    visited=[False]*100001
    dq=deque()
    dq.append((v, 0))

    visited[v]=True
    while(dq):
        curr_pos,curr_time=dq.popleft()
        if curr_pos == target_pos:
            return curr_time
        else:
            next_pos=[curr_pos-1,curr_pos+1,curr_pos*2]
            for pos in next_pos:
                if 0<=pos<=100000 and not visited[pos]:
                    visited[pos] =True
                    # print(f'pos{pos}time{curr_time}')
                    dq.append((pos,curr_time+1))

print(bfs(N,K))
# Out:
# pos4time0
# pos6time0
# pos10time0
# pos3time1
# pos8time1
# pos7time1
# pos12time1
# pos9time1
# pos11time1
# pos20time1
# pos2time2
# pos16time2
# pos14time2
# pos13time2
# pos24time2
# pos18time2
# pos22time2
# pos19time2
# pos21time2
# pos40time2
# pos1time3
# pos15time3
# pos17time3
# pos32time3
# pos28time3
# pos26time3
# pos23time3
# pos25time3
# pos48time3
# pos36time3
# pos44time3
# pos38time3
# pos42time3
# pos39time3
# pos41time3
# pos80time3
# pos0time4
# pos30time4
# 4
